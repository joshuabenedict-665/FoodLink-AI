# %% [markdown]
# <a href="https://colab.research.google.com/github/joshuabenedict-665/FoodLink-AI/blob/main/FoodLinkAI_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic setup
# !pip install pandas scikit-learn joblib

# %%
from google.colab import files
files.upload()  # Upload your kaggle.json here
# Out:
#      <input type="file" id="files-6f1186d8-79a8-40aa-a91d-3394300d9534" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f1186d8-79a8-40aa-a91d-3394300d9534">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d ameymore/food-quality-assessment
# !unzip food-quality-assessment.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ameymore/food-quality-assessment
# License(s): unknown
# ...
#   0% 0.00/15.2M [00:00<?, ?B/s]
# 100% 15.2M/15.2M [00:00<00:00, 906MB/s]
# Archive:  food-quality-assessment.zip
#   inflating: Data_Test.xlsx
#   inflating: Data_Train.xlsx
#   inflating: Sample_Submission.xlsx

# %%
import pandas as pd

train_df = pd.read_excel("Data_Train.xlsx")
train_df.head()
# Out:
#                ID        Date  LicenseNo  FacilityID  FacilityName  \
# 0  31103489027986  26-04-2010       4744        8123          7715
# 1  10088999935915  21-06-2009       2973       12268         11664
# 2  40148966010272  01-05-2013      18223        1112           969
# 3  37157708563676  28-09-2015      20825       20007         19115
# 4  47478049564374  09-12-2015       2136       16867         10409
#
#             Type  Street         City       State  LocationID  \
# 0     RESTAURANT   15522  id-11235901  id_1890134     81876.0
# 1  GROCERY STORE    3057  id-11235901  id_1890134     81862.0
# 2     RESTAURANT   14988  id-11235901  id_1890134     81883.0
# 3     RESTAURANT    3661  id-11235901  id_1890134     81859.0
# 4     RESTAURANT    7876  id-11235901  id_1890134     81886.0
#
#                   Reason  SectionViolations RiskLevel     Geo_Loc  \
# 0                CANVASS               33.0      High  locid16406
# ...
